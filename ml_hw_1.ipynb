# %%
import glob

# Importing drive method from colab for accessing google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import random
import os
import tensorflow as tf

DATA_PATH = "/content/drive/My Drive"

# Get label names
CLASSES = []
for dir in sorted(os.listdir(DATA_PATH + "/ml/training_data")):
    CLASSES.append(dir)

# Load training_data
DATA_PATH = "/content/drive/My Drive"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(DATA_PATH + "/ml/training_data",
                                                                    label_mode="categorical",
                                                                    image_size=(256, 256),
                                                                    class_names=CLASSES,
                                                                    seed=random.randint(0, 1000000))
# Out:
# Found 11185 files belonging to 196 classes.

# %%
from tensorflow.keras.layers import AveragePooling2D, Dropout, Flatten, Dense

# Model based on incpetion_v3 
def create_model(num_classes, dropout_rate):
    base = tf.keras.applications.InceptionV3(include_top=False, weights=None, input_shape=(256, 256, 3))
    x = base.get_layer("mixed10").output
    x = AveragePooling2D(pool_size=(6, 6), padding="valid")(x)
    x = Dropout(dropout_rate)(x)
    x = Flatten()(x)
    x = Dense(units=num_classes, activation="softmax")(x)

    model = tf.keras.Model(base.input, x)
    model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

    return model

# %%
# Train and save results
model = create_model(num_classes=196, dropout_rate=0.2)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=DATA_PATH + "/ml/model/training_5/cp.ckpt",
                                                 save_weights_only=True,
                                                 verbose=1)
model.fit(train_ds, epochs=50, callbacks=[cp_callback])
# Out:
# Epoch 1/50
# 350/350 [==============================] - ETA: 0s - loss: 5.3233 - accuracy: 0.0131
# Epoch 00001: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 2313s 7s/step - loss: 5.3233 - accuracy: 0.0131
# Epoch 2/50
# 350/350 [==============================] - ETA: 0s - loss: 5.0559 - accuracy: 0.0182
# Epoch 00002: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 164s 469ms/step - loss: 5.0559 - accuracy: 0.0182
# Epoch 3/50
# 350/350 [==============================] - ETA: 0s - loss: 4.8697 - accuracy: 0.0257
# Epoch 00003: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 4.8697 - accuracy: 0.0257
# Epoch 4/50
# 350/350 [==============================] - ETA: 0s - loss: 4.5881 - accuracy: 0.0386
# Epoch 00004: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 466ms/step - loss: 4.5881 - accuracy: 0.0386
# Epoch 5/50
# 350/350 [==============================] - ETA: 0s - loss: 4.2640 - accuracy: 0.0585
# Epoch 00005: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 464ms/step - loss: 4.2640 - accuracy: 0.0585
# Epoch 6/50
# 350/350 [==============================] - ETA: 0s - loss: 3.9552 - accuracy: 0.0847
# Epoch 00006: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 3.9552 - accuracy: 0.0847
# Epoch 7/50
# 350/350 [==============================] - ETA: 0s - loss: 3.6022 - accuracy: 0.1227
# Epoch 00007: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 463ms/step - loss: 3.6022 - accuracy: 0.1227
# Epoch 8/50
# 350/350 [==============================] - ETA: 0s - loss: 3.1797 - accuracy: 0.1848
# Epoch 00008: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 3.1797 - accuracy: 0.1848
# Epoch 9/50
# 350/350 [==============================] - ETA: 0s - loss: 2.7561 - accuracy: 0.2672
# Epoch 00009: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 464ms/step - loss: 2.7561 - accuracy: 0.2672
# Epoch 10/50
# 350/350 [==============================] - ETA: 0s - loss: 2.3516 - accuracy: 0.3469
# Epoch 00010: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 463ms/step - loss: 2.3516 - accuracy: 0.3469
# Epoch 11/50
# 350/350 [==============================] - ETA: 0s - loss: 1.9875 - accuracy: 0.4392
# Epoch 00011: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 1.9875 - accuracy: 0.4392
# Epoch 12/50
# 350/350 [==============================] - ETA: 0s - loss: 1.6670 - accuracy: 0.5135
# Epoch 00012: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 462ms/step - loss: 1.6670 - accuracy: 0.5135
# Epoch 13/50
# 350/350 [==============================] - ETA: 0s - loss: 1.4060 - accuracy: 0.5824
# Epoch 00013: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 1.4060 - accuracy: 0.5824
# Epoch 14/50
# 350/350 [==============================] - ETA: 0s - loss: 1.1629 - accuracy: 0.6410
# Epoch 00014: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 464ms/step - loss: 1.1629 - accuracy: 0.6410
# Epoch 15/50
# 350/350 [==============================] - ETA: 0s - loss: 0.9985 - accuracy: 0.6917
# Epoch 00015: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.9985 - accuracy: 0.6917
# Epoch 16/50
# 350/350 [==============================] - ETA: 0s - loss: 0.8296 - accuracy: 0.7381
# Epoch 00016: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 466ms/step - loss: 0.8296 - accuracy: 0.7381
# Epoch 17/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6950 - accuracy: 0.7729
# Epoch 00017: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 164s 467ms/step - loss: 0.6950 - accuracy: 0.7729
# Epoch 18/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6109 - accuracy: 0.7996
# Epoch 00018: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 164s 468ms/step - loss: 0.6109 - accuracy: 0.7996
# Epoch 19/50
# 350/350 [==============================] - ETA: 0s - loss: 0.5420 - accuracy: 0.8212
# Epoch 00019: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 467ms/step - loss: 0.5420 - accuracy: 0.8212
# Epoch 20/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4717 - accuracy: 0.8455
# Epoch 00020: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.4717 - accuracy: 0.8455
# Epoch 21/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4038 - accuracy: 0.8676
# Epoch 00021: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 164s 470ms/step - loss: 0.4038 - accuracy: 0.8676
# Epoch 22/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3775 - accuracy: 0.8750
# Epoch 00022: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 164s 470ms/step - loss: 0.3775 - accuracy: 0.8750
# Epoch 23/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3200 - accuracy: 0.8956
# Epoch 00023: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 164s 468ms/step - loss: 0.3200 - accuracy: 0.8956
# Epoch 24/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3273 - accuracy: 0.8896
# Epoch 00024: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 466ms/step - loss: 0.3273 - accuracy: 0.8896
# Epoch 25/50
# 350/350 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.9015
# Epoch 00025: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.2871 - accuracy: 0.9015
# Epoch 26/50
# 350/350 [==============================] - ETA: 0s - loss: 0.2674 - accuracy: 0.9123
# Epoch 00026: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 464ms/step - loss: 0.2674 - accuracy: 0.9123
# Epoch 27/50
# 350/350 [==============================] - ETA: 0s - loss: 0.2279 - accuracy: 0.9272
# Epoch 00027: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 462ms/step - loss: 0.2279 - accuracy: 0.9272
# Epoch 28/50
# 350/350 [==============================] - ETA: 0s - loss: 0.2440 - accuracy: 0.9199
# Epoch 00028: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 464ms/step - loss: 0.2440 - accuracy: 0.9199
# Epoch 29/50
# 350/350 [==============================] - ETA: 0s - loss: 0.2306 - accuracy: 0.9248
# Epoch 00029: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 161s 461ms/step - loss: 0.2306 - accuracy: 0.9248
# Epoch 30/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1899 - accuracy: 0.9378
# Epoch 00030: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.1899 - accuracy: 0.9378
# Epoch 31/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9463
# Epoch 00031: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 462ms/step - loss: 0.1676 - accuracy: 0.9463
# Epoch 32/50
# 350/350 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9279
# Epoch 00032: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 463ms/step - loss: 0.2210 - accuracy: 0.9279
# Epoch 33/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9407
# Epoch 00033: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 463ms/step - loss: 0.1837 - accuracy: 0.9407
# Epoch 34/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9473
# Epoch 00034: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 462ms/step - loss: 0.1613 - accuracy: 0.9473
# Epoch 35/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9434
# Epoch 00035: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 463ms/step - loss: 0.1800 - accuracy: 0.9434
# Epoch 36/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1738 - accuracy: 0.9439
# Epoch 00036: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 463ms/step - loss: 0.1738 - accuracy: 0.9439
# Epoch 37/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9494
# Epoch 00037: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.1541 - accuracy: 0.9494
# Epoch 38/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.9613
# Epoch 00038: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 462ms/step - loss: 0.1215 - accuracy: 0.9613
# Epoch 39/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9533
# Epoch 00039: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 162s 464ms/step - loss: 0.1425 - accuracy: 0.9533
# Epoch 40/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1627 - accuracy: 0.9463
# Epoch 00040: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.1627 - accuracy: 0.9463
# Epoch 41/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9529
# Epoch 00041: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.1386 - accuracy: 0.9529
# Epoch 42/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9560
# Epoch 00042: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 467ms/step - loss: 0.1349 - accuracy: 0.9560
# Epoch 43/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9593
# Epoch 00043: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.1309 - accuracy: 0.9593
# Epoch 44/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9726
# Epoch 00044: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 464ms/step - loss: 0.0909 - accuracy: 0.9726
# Epoch 45/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9559
# Epoch 00045: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.1357 - accuracy: 0.9559
# Epoch 46/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9691
# Epoch 00046: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.0991 - accuracy: 0.9691
# Epoch 47/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1318 - accuracy: 0.9583
# Epoch 00047: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 164s 469ms/step - loss: 0.1318 - accuracy: 0.9583
# Epoch 48/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9661
# Epoch 00048: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 163s 465ms/step - loss: 0.1010 - accuracy: 0.9661
# Epoch 49/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9644
# Epoch 00049: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 164s 469ms/step - loss: 0.1135 - accuracy: 0.9644
# Epoch 50/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1144 - accuracy: 0.9641
# Epoch 00050: saving model to /content/drive/My Drive/ml/model/training_5/cp.ckpt
# 350/350 [==============================] - 164s 467ms/step - loss: 0.1144 - accuracy: 0.9641
